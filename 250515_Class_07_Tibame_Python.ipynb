# %% [markdown]
# <a href="https://colab.research.google.com/github/kheit9527/2025_Tibame_Python/blob/main/250515_Class_07_Tibame_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req

url = "https://github.com/Elwing-Chou/tiba_night_0422/raw/refs/heads/main/chiikawa.csv"
req.urlretrieve(url, "chiikawa.csv")
# Out:
# ('chiikawa.csv', <http.client.HTTPMessage at 0x7a33a3d445d0>)

# %%
import pandas as pd
df = pd.read_csv("chiikawa.csv", encoding = "utf-8", index_col = 0) # df = DataFrame
df
# Out:
#         text    color  size  position  time        sn      userid
# 0     謝謝巴哈大哥  #FFFFFF     1         0     0  37089407     s970446
# 1        第一次  #FFFFFF     1         0     0  39557840   wex690825
# 2        0.0  #FFFFFF     1         0     0  40729192   z80262001
# 3          耶  #FFFFFF     1         0     0  41875955   ouyang318
# 4         二刷  #FFFFFF     1         0     0  42903755  qaz1210731
# ..       ...      ...   ...       ...   ...       ...         ...
# 494      ZMB  #FFFFFF     1         0   877  42527612     ZED8090
# 495  兄弟有事請轉身  #FFFFFF     1         0   890  44754781    D0690422
# 496        😀  #00C3FC     1         0   898  40894473   kekerry75
# 497   沒了？？？？  #FFFFFF     1         0   901  42188563      linzzi
# 498        哈  #FF0026     1         0   901  44529579   st5109185
#
# [499 rows x 7 columns]

# %%
# and(&) or(|)
fil = (df["time"] > 630) & (df["time"] < 720)
df[fil]
# Out:
#                     text    color  size  position  time        sn  \
# 351              yuuyuyu  #FFFFFF     1         1   631  43103312
# 352  想像氷川日菜（CV小澤亞里）在幕後鬼叫  #FFFFFF     1         0   634  37110322
# 353                   晚安  #FFFFFF     1         0   637  44440673
# 354     什麼結束了！？我到底看了什麼？？  #0036FA     2         2   641  44139947
# 355                 趴！沒了  #FFFFFF     1         0   642  41322892
# ..                   ...      ...   ...       ...   ...       ...
# 414                   可以  #FFFFFF     1         0   714  42679294
# 415               ？？？？？？  #FFFFFF     1         0   715  44405211
# 416             小八在結尾 可愛  #FFFFFF     1         0   717  37340486
# 417                西西不西西  #FFFFFF     1         0   717  44529568
# 418               真的體感3秒  #FFFFFF     1         0   719  37884256
#
#            userid
# 351     chenyin09
# 352     ol0SOW0lo
# 353     jimmy0416
# 354      SUDU9527
# 355  z9ha45pt26xo
# ..            ...
# 414       cyc0321
# ...

# %%
df["userid"].value_counts()
# Out:
# userid
# st5109185       10
# annana566        7
# g840483938       6
# Bananaaa         4
# vicky220         4
#                 ..
# llennskadi       1
# designer22       1
# IamBongu0626     1
# nxjhcfynvq       1
# redskycity       1
# Name: count, Length: 388, dtype: int64

# %%
filter = df["userid"] == "Bananaaa"
df[filter]
# Out:
#         text    color  size  position  time        sn    userid
# 98     截圖當桌布  #FFFFFF     1         0   125  40271962  Bananaaa
# 160      黏黏黏  #FFFFFF     1         0   220  40271970  Bananaaa
# 270   為什麼要拍？  #FFFFFF     1         0   465  40271978  Bananaaa
# 312  看起來也太好吃  #FFFFFF     1         0   535  40271980  Bananaaa

# %% [markdown]
# ```
# 先右鍵，查看網頁原始碼，看有沒有答案
# 沒有答案，再F12，找隱藏網址
# ```
